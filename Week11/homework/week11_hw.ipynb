# %% [markdown]
# # Week 11 Homework
#
# Write a class that generates fake data.
#
# * Write the code under the py docs ( do NOT remove docs strings)
# * Before comitting do a Restart & Run All
#
# Make sure that if a dataframe is passed in, it should not remove any value from it.

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\nitya\anaconda3\lib\site-packages (8.13.2)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\nitya\anaconda3\lib\site-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\nitya\anaconda3\lib\site-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\nitya\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import numpy as np
import random
fakeit = Faker()

# %%
class FakeDataGenerator:
    
    def __init__(self, df = None, rows=25):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` lenght
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments
        
        
        if df is None:
            df = pd.DataFrame(index=np.arange(rows))
            self.df = df
            self.rows = len(df)
        else:
            self.df = df
            self.rows = rows
       
    
        
       
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Return
        -------
        data frame
        """
        number=[]
        self.small_value=small_value
        self.high_value=high_value
        for i in range(len(df)):
            number.append(random.randint(self.small_value,self.high_value))
        self.df[column_name]=number
        return self.df      
            
    def add_first_name(self, column_name):   
        """
        adds fake first name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.df[column_name] = [fakeit.first_name() for i in range(len(df))]
        return self.df
    
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.df[column_name] = [fakeit.last_name() for i in range(len(df))]
        
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.df[column_name] = [fakeit.email() for i in range(len(df))]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.df[column_name] = [fakeit.phone_number() for i in range(len(df))]
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.df[column_name] = [fakeit.address() for i in range(len(df))]
        
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('numbr',10,25)
# Out:
#     product_id                                   shipping_address  \
# 0          123                   PSC 5908, Box 0927\nAPO AP 33640
# 1          124            2713 Torres Island\nJoyceview, WV 04459
# 2          125            610 Black Junctions\nJohnport, TN 08404
# 3          126  07053 Amanda Shoals Apt. 673\nWrightview, AK 6...
# 4          127  051 Fletcher Stravenue Suite 363\nHenrystad, S...
# 5          128           584 Megan Route\nWest Kimberly, MA 77838
# 6          129        450 Brandy Via Apt. 913\nLynnfort, MN 39139
# 7          130  78847 Collins Lodge Suite 876\nEast Ashley, NY...
# 8          131  331 Henderson Causeway Suite 743\nPort Patrici...
# 9          132  1786 Thompson Cliff Suite 372\nRubioport, GA 1...
# 10         133  360 Victoria Junctions\nJacquelineshire, MI 45914
# 11         134            36706 Dawn Lake\nPhillipsport, TX 86231
# 12         135           2947 Shane Locks\nJenniferberg, TX 46906
# 13         136  90515 Thompson Well Suite 851\nJohnsfurt, OH 9...
# 14         137  742 Robert Hills Apt. 883\nPort Josephville, U...
# 15         138  04676 Romero Ramp Suite 548\nNew Cynthiatown, ...
# 16         139  35728 Taylor Knolls Suite 256\nLake Marcustown...
# 17         140  392 Williams Fords Apt. 328\nComptonbury, AL 9...
# 18         141                503 Erin Flat\nWest David, GA 30917
# 19         142                   Unit 8646 Box 2838\nDPO AA 50274
# 20         143  240 Adams Island Apt. 804\nSouth Ambertown, MO...
# 21         144          0231 Harris Cove\nWest Jennifer, FL 37448
# 22         145  65442 Kristy Forest Apt. 856\nPort Anthony, WY...
# 23         146  81125 David Junction Suite 119\nLake Peter, NJ...
# 24         147              491 Keith Route\nCathyhaven, TX 63321
#
#                                       billing_address          customer_phone  \
# 0             0269 Kirby Track\nCharlestown, NE 40456  001-860-974-8382x18278
# 1                    PSC 9416, Box 5112\nAPO AE 89551       591.409.5254x1357
# 2           03737 Lisa Flat\nLake Tylerbury, WV 53508              5304886115
# 3           7228 Renee Circle\nWest Timothy, OK 72032    001-254-439-8501x481
# 4        8422 Angelica Garden\nWest Tiffany, MS 53993        001-637-711-6757
# 5                    Unit 6478 Box 7771\nDPO AP 05197    +1-817-299-3013x5593
# 6   212 David Ville Apt. 429\nPort Christopher, DE...            752.546.4805
# 7              99410 Lauren Ways\nBrowntown, WY 62804       647-709-1495x5928
# 8   7848 Jacob Port Suite 099\nRobinsonmouth, UT 0...           (302)535-5891
# 9                         USNS Phillips\nFPO AA 88673           (640)142-1938
# 10  3632 Alexandra Neck Suite 310\nNorth Williammo...      102-751-9748x97650
# 11          561 Rodriguez Road\nMarcusmouth, MI 72056   001-589-301-0466x3981
# 12  761 Scott Skyway Suite 687\nChurchburgh, OK 63056              0314982370
# 13                   PSC 0660, Box 8383\nAPO AE 17998   +1-802-980-2490x59787
# 14                   Unit 6598 Box 5579\nDPO AP 41556     +1-004-503-7579x475
# 15  55098 Anthony Turnpike Apt. 816\nSouth Jeremyp...     (882)110-9286x01010
# 16                   PSC 6206, Box 0429\nAPO AP 28111    001-445-284-7002x388
# 17     2130 Jones Island Apt. 022\nMayoberg, SD 78210            927.915.3302
# 18    43224 Smith Overpass\nEast Rachelfurt, VT 49974         +1-818-313-5469
# 19          439 Garcia Crossing\nDanielport, WA 53491      (264)185-5502x2848
# 20       6863 Morgan Run\nWest Cheyennefort, ME 44532        001-799-030-2813
# 21  73024 Allen Valleys Apt. 579\nGardnerhaven, NJ...       455-787-4894x2717
# 22      111 Sandoval Crescent\nWest Jeffery, TN 00860   +1-751-692-3024x12627
# 23                         USCGC Foster\nFPO AE 45965            686-009-3541
# 24      714 Tina Overpass\nPort Jessicatown, VA 63783              2547704755
#
#     numbr
# 0      17
# 1      18
# 2      22
# 3      23
# 4      12
# 5      22
# 6      25
# 7      23
# 8      21
# 9      25
# 10     17
# 11     12
# 12     11
# 13     14
# 14     24
# 15     15
# 16     11
# 17     15
# 18     17
# 19     14
# 20     25
# 21     22
# 22     21
# 23     25
# 24     11

# %%
# Case 2- no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                      shipping_address  \
# 0   89370 Shelly Knoll Apt. 096\nEast Amandaton, P...
# 1       60795 Joseph Flats\nWest Normanview, VT 39646
# 2       8588 Danielle Meadows\nLake Michael, DE 46468
# 3       461 Parker Island\nEast Justinhaven, NJ 68659
# 4           2193 Justin Curve\nChelseaburgh, NV 15111
# 5                           USNV Santos\nFPO AE 90515
# 6      54560 Laura Via Suite 661\nLake Omar, MI 57223
# 7                           USCGC Flynn\nFPO AE 18671
# 8                             USNV Long\nFPO AE 70302
# 9    43081 Wendy Lights Apt. 487\nNew Tammy, SD 84370
# 10                   Unit 6892 Box 9364\nDPO AA 32649
# 11  96742 Heather Corners Apt. 512\nNew Andrewmout...
# 12  655 Martin Mission Apt. 014\nSouth Miranda, MA...
# 13        071 Rogers Crest\nNew Jessicafurt, CA 48604
# 14  02806 Rachel Shoals Apt. 773\nJohnsonville, VT...
# 15  679 Cathy Islands Suite 485\nNew Amandaport, D...
# 16        678 Ian Oval Suite 696\nAmandaton, IA 60389
# 17  54564 Rice Ramp Suite 576\nDavenportside, CA 2...
# 18          007 Lopez Crossroad\nSouth Gary, NM 56143
# 19          55599 Harris Harbors\nHollyberg, WI 47910
# 20  9394 Larry Lights Suite 384\nDarrellborough, M...
# 21      1656 Kristin Village\nEast Samantha, TN 62980
# 22          80312 Brandy Green\nRhondamouth, IA 02647
# 23  070 Johnson Valley Suite 164\nNorth Michaelton...
# 24  126 Fox Tunnel Suite 148\nSouth Sandraport, ME...
#
#                                       billing_address         customer_phone  \
# 0                 6106 Shawn Key\nNancyfurt, VA 19472          (326)762-1257
# 1     905 Amanda Port Suite 675\nRachelview, WA 82825    +1-252-518-1060x998
# 2             0971 Lisa Unions\nNorth Kelly, MO 39297       742-836-6091x202
# 3   2234 Robin Tunnel Suite 663\nEast Johnmouth, M...           017.257.8575
# 4              2381 Russell Road\nPort Brad, NM 43163      (570)877-0610x645
# 5            85499 Daniel Mills\nWalkerberg, FL 90350   001-635-807-7341x201
# 6        193 Madison Court\nEast Denisefurt, PA 55388  001-418-492-4934x6191
# 7     69531 Patel Lane Apt. 861\nDavidmouth, OH 08146   +1-895-591-8099x0141
# 8                    Unit 7790 Box 4809\nDPO AP 79868           931.216.9203
# 9   1163 Austin Squares Apt. 532\nNorth Brandi, WA...      464.691.0476x8493
# 10  12534 Ashley Lodge Apt. 932\nAustinfurt, NJ 10801        +1-984-948-7494
# 11   707 Turner Creek Apt. 497\nPort Andrew, NM 97467           307-419-5372
# 12  0386 Michael Cape Suite 297\nSouth Wanda, NH 6...           198.287.7721
# 13   4247 Cody Courts Suite 488\nDillonside, MD 79881             0523198877
# 14  9898 Higgins Lights Suite 266\nSouth Joseph, I...      959.723.2826x7118
# 15   74566 Robin Road Suite 913\nYounghaven, WA 06496             3215390583
# 16    494 Justin Creek Apt. 726\nZavalatown, ME 56123          (626)551-0109
# 17          921 Bender Run\nPort Danielstad, NH 95470  +1-220-825-4424x71936
# 18           65582 Susan Course\nMillerfort, DC 72207   +1-268-652-9592x3150
# 19             00544 Curtis Burg\nScotttown, WI 41916     (040)213-8885x0837
# 20   9591 Zavala Camp Apt. 592\nLaurieburgh, AL 57520       040.316.3736x853
# 21                         USCGC Martin\nFPO AE 63499    +1-633-850-0289x123
# 22  84655 Bowers Common Suite 830\nBradleyfort, NV...       190-628-7371x594
# 23  961 Victoria Lodge Suite 133\nWalkertown, CO 9...    +1-230-085-3631x930
# 24  770 Colleen Roads Suite 947\nSouth Jerry, MD 1...    (134)110-7712x96868
#
#     sale_count
# 0           11
# 1           92
# 2           48
# 3           22
# 4           78
# 5           86
# 6           78
# 7           32
# 8           53
# 9           67
# 10          66
# 11          67
# 12          79
# 13          52
# 14          17
# 15          79
# 16          58
# 17          36
# 18          43
# 19          81
# 20          91
# 21          61
# 22          44
# 23          71
# 24          15
